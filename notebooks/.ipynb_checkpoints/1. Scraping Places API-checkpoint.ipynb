# %% [markdown]
# ## First Attempt

# %%
tags = [
    'tourist_attraction',
    'restaurant',
    'campground',
    'amusement_park', 
    'zoo',
    'hindu_temple',
    'mosque',
    'church',
    'synagogue',
    'lodging'
]
len(tags)

# %% [markdown]
# <h4>Importing required libraries</h4>

# %%
import requests
import json
import os

# %% [markdown]
# <h4>Creating list of <i>place_types</i> for each of 4 users: <u>FOTEDAR</u>, <u>SHANDILYA</u>, <u>SHETTY</u> and <u>DANGWAL</u></h4>

# %%
s = """airport
amusement_park
aquarium
art_gallery
atm
bakery
bar
book_store
bowling_alley
bus_station
cafe
campground
car_rental
casino
church
embassy
food
gas_station
hindu_temple
hospital
library
light_rail_station
liquor_store
lodging
meal_delivery
meal_takeaway
mosque
movie_theater
museum
night_club
park
police
restaurant
rv_park
shopping_mall
spa
stadium
subway_station
synagogue
taxi_stand
tourist_attraction
train_station
transit_station
zoo"""

tags = s.split('\n')

FOTEDAR = tags[1:15]
SHANDILYA = tags
SHETTY = tags[15:31]
DANGWAL = tags[31:]

# %%
tags = [
    'tourist_attraction',
    'restraunt',
    'rv_park',
    'campground',
    'amusement_park', 
    'zoo',
    'hindu_temple',
    'mosque',
    'church',
    'synagogue',
    'lodging'
]
len(tags)
# Out:
# 11

# %% [markdown]
# <h4>Below is the function which will call the places API and get information as per the `place_types`.</h4>

# %%
API = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
QUERY_PLACE = 'aurangabad+'
FIELDS = 'id,formatted_address,geometry,name,place_id,price_level,plus_code,types,rating,user_ratings_total,opening_hours,business_status'
NAMES = {
    'FOTEDAR': FOTEDAR, 
    'SHANDILYA': SHANDILYA, 
    'SHETTY': SHETTY,
    'DANGWAL': DANGWAL
}

def get_data(API_KEY, NAME):
    if NAME in NAMES.keys():
        place_types = NAMES[NAME]
        for t in place_types:
            URL = API + 'query=' + QUERY_PLACE + t + '&key=' + API_KEY + \
            '&fields=' + FIELDS
            resp = requests.get(URL)
            if resp.status_code == 200:
                JSONContent = resp.json()
                content = json.dumps(JSONContent, indent = 4, sort_keys=True)
                FILE_NAME = './data/' + QUERY_PLACE + t + '.json'
                if not os.path.exists('data'):
                    os.makedirs('data')
                with open(FILE_NAME, 'w') as o:
                    o.write(content)
                print(f'Downloaded data: {FILE_NAME}')
            else:
                print(f'Problem with query: \n {URL}')
    else:
        print(f'Enter correct name either: FOTEDAR, SHANDILYA, SHETTY or DANGWAL')

# %%
API = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
QUERY_PLACE = 'aurangabad'
FIELDS = 'id,formatted_address,geometry,name,place_id,price_level,plus_code,types,rating,user_ratings_total,opening_hours,business_status'

def get_tag_data(API_KEY, tags, QUERY_PLACE):
    for tag in tags:
        URL = API + 'query=' + QUERY_PLACE + '+' + tag + '&key=' + API_KEY +\
            '&fields=' + FIELDS
        resp = requests.get(URL)
        if resp.status_code == 200:
            JSONContent = resp.json()
            content = json.dumps(JSONContent, indent=4, sort_keys=True)
            FILE_NAME = './data/' + QUERY_PLACE + '/' + QUERY_PLACE + '_' + tag + '.json'
            if not os.path.isdir('data'):
                os.makedirs('data')
            retval = os.getcwd()
            pat = retval + '/data/' + QUERY_PLACE
            if not os.path.isdir(pat):
                os.makedirs('data/' + QUERY_PLACE)
            with open(FILE_NAME, 'w') as o:
                o.write(content)
            
            print(f'Download data: {FILE_NAME}')
        else:
            print(f'Problem with query: \n {URL}')

# %%
def get_tags_data(API_KEY, tags, query_place):
    for tag in tags:
        URL = API + 'query=' + query_place + '+' + tag + '&key=' + API_KEY +\
            '&fields=' + FIELDS
        content = get_json_data()
        check_directory_present(query_place)
        count = 1
        while(hasattr(content, 'next_page_token')):
            file_name = './data/' + query_place + '/' + query_place + '_' + \
            count + '_' + tag + '.json'
            count += 1
            save_json_file(content, file_name)
            content = get_json_data()
            
        file_name = './data/' + query_place + '/' + query_place + '_' + \
            count + '_' + tag + '.json'
        save_json_file(content, file_name)

# %%
def get_json_data(URL, file):
    resp = requests.get(URL)
    if resp.status_code == 200:
        content = json.dumps(JSONContent, indent=4, sort_keys=True)
    return content


def check_directory_present(query_place):
    if not os.path.isdir('data'):
        os.makedirs('data')
    retval = os.getcwd()
    pat = retval + '/data/' + query_place
    if not os.path.isdir(pat):
        os.makedirs('./data/' + query_place)

        
def save_json_file(content, file_name):
    with open(file_name, 'w') as o:
        o.write(content)

# %% [markdown]
# <h4>Store your API key below.</h4>

# %%
KEY = 'AIzaSyCDEKdeYkcA467-INwrPOXnU_PU_Bc2RmQ'

# %% [markdown]
# <h4>Call the function get_data provide it with API key and your name:
#
#     - FOTEDAR
#     - SHANDILYA
#     - SHETTY
#     - DANGWAL
#
# </h4>

# %%
get_tags_data(KEY, tags, 'goa')
# Out:
# Download data: ./data/goa/goa_airport.json
# Download data: ./data/goa/goa_amusement_park.json
# Download data: ./data/goa/goa_aquarium.json
# Download data: ./data/goa/goa_art_gallery.json
# Download data: ./data/goa/goa_atm.json
# Download data: ./data/goa/goa_bakery.json
# Download data: ./data/goa/goa_bar.json
# Download data: ./data/goa/goa_book_store.json
# Download data: ./data/goa/goa_bowling_alley.json
# Download data: ./data/goa/goa_bus_station.json
# Download data: ./data/goa/goa_cafe.json
# Download data: ./data/goa/goa_campground.json
# Download data: ./data/goa/goa_car_rental.json
# Download data: ./data/goa/goa_casino.json
# Download data: ./data/goa/goa_church.json
# Download data: ./data/goa/goa_embassy.json
# Download data: ./data/goa/goa_gas_station.json
# Download data: ./data/goa/goa_hindu_temple.json
# Download data: ./data/goa/goa_hospital.json
# Download data: ./data/goa/goa_library.json
# Download data: ./data/goa/goa_light_rail_station.json
# ...

# %% [markdown]
# ### JSON to CSV

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
def create_df_from_json(direc):
    """
    This function loops through all json file in a particular sub-directory
    of `data` directory.
    Converts them into a pandas dataframe.
    Returns the dataframe.
    """
    df_merged = pd.DataFrame()
    pat = direc + '_([a-z]+_?[a-z]+_*[a-z]+)*(.json$)'
    prog = re.compile(pat)
    directory = r'data/' + direc
    for file in os.scandir(directory):
        if(file.path.endswith('.json')):
            with open(file, encoding='utf-8') as f:
                d = json.load(f)
                result = prog.match(file.name)
                tag = result.group(1)
                if len(d['results']) == 0:
                    df = pd.DataFrame.from_dict({'results': [0]})
                else:
                    df = pd.DataFrame.from_dict(d['results'])
                df['tag'] = tag
                if 'next_page_token' in d.keys():
                    df['next_page_token'] = d['next_page_token']
                else:
                    df['next_page_token'] = None
                if d['status'] == 'ZERO_RESULTS':
                    df['no_of_results'] = 0
                else:
                    df['no_of_results'] = len(d['results']) 
        if df_merged.empty:
            df_merged = df
        else:
            df_merged = pd.concat([df_merged, df], axis=0, ignore_index=True)
    df_merged.to_csv('data/csv/' + direc + '.csv')
    return df_merged

# %%
with open('data/aurangabad/aurangabad_tourist_attraction_3.json', encoding='utf-8') as f:
    d = json.load(f)
    awb = pd.DataFrame.from_dict(d['results'])
    awb.to_csv('data/csv/awb.csv')

# %%
len(awb)
# Out:
# 60

# %%
df = create_df_from_json('aurangabad')

# %%
df_awb = pd.read_csv('data/csv/aurangabad.csv')
df_goa = pd.read_csv('data/csv/goa.csv')

# %%
df_awb.head()
# Out:
#    Unnamed: 0     business_status  \
# 0           0         OPERATIONAL
# 1           1  CLOSED_TEMPORARILY
# 2           2         OPERATIONAL
# 3           3  CLOSED_TEMPORARILY
# 4           4  CLOSED_TEMPORARILY
#
#                                    formatted_address  \
# 0  Jalna Road, Chilkalthana, Aurangabad, Maharash...
# 1  BACKSIDE OF PATEL LAWNS, H.NO137 P.NO37 ABRAR ...
# 2  3-8-286, Sanjay Nagar, Mondha, Aurangabad, Mah...
# 3  NH 211, Vitkheda - Ellora Rd, near Daulatabad,...
# 4              Daulatabad, Maharashtra 431002, India
#
#                                             geometry  \
# 0  {'location': {'lat': 19.8673554, 'lng': 75.395...
# 1  {'location': {'lat': 19.8547242, 'lng': 75.310...
# 2  {'location': {'lat': 19.8827237, 'lng': 75.344...
# 3  {'location': {'lat': 19.9558, 'lng': 75.222134...
# 4  {'location': {'lat': 19.9528817, 'lng': 75.222...
#
#                                                 icon  \
# ...

# %%
df_goa.head()
# Out:
#    Unnamed: 0 business_status  \
# 0           0     OPERATIONAL
# 1           1     OPERATIONAL
# 2           2     OPERATIONAL
# 3           3     OPERATIONAL
# 4           4     OPERATIONAL
#
#                                    formatted_address  \
# 0             Airport Rd, Dabolim, Goa 403801, India
# 1  Calangute-Anjuna Main Road, Padre Agnel Vaddo,...
# 2                            Padi, Goa 403703, India
# 3  Quepem Market Road, Nirmal Nagar, Xeldem, Goa ...
# 4        Gudi, Quepem Rd, Chandor, Goa 403714, India
#
#                                             geometry  \
# 0  {'location': {'lat': 15.3803485, 'lng': 73.834...
# 1  {'location': {'lat': 15.579003, 'lng': 73.7587...
# 2  {'location': {'lat': 15.0893788, 'lng': 74.056...
# 3  {'location': {'lat': 15.2377093, 'lng': 74.076...
# 4  {'location': {'lat': 15.2423522, 'lng': 74.032...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# ...

# %%
df_awb.iloc[0]['geometry']
# Out:
# "{'location': {'lat': 19.8673554, 'lng': 75.39579599999999}, 'viewport': {'northeast': {'lat': 19.86897092989272, 'lng': 75.3971448798927}, 'southwest': {'lat': 19.86627127010728, 'lng': 75.39444522010727}}}"

# %%
df_awb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          506 non-null    int64
#  1   business_status     491 non-null    object
#  2   formatted_address   495 non-null    object
#  3   geometry            495 non-null    object
#  4   icon                495 non-null    object
#  5   id                  495 non-null    object
#  6   name                495 non-null    object
#  7   photos              372 non-null    object
#  8   place_id            495 non-null    object
#  9   plus_code           480 non-null    object
#  10  rating              492 non-null    float64
#  11  reference           495 non-null    object
#  12  types               495 non-null    object
#  13  user_ratings_total  492 non-null    float64
#  14  tag                 506 non-null    object
# ...

# %%
df_awb_cleaned = df_awb.drop(['Unnamed: 0', 'formatted_address', 'icon', 
                             'id', 'photos', 'reference', 'next_page_token',],
                            axis=1)

# %%
df_awb_cleaned.head()
# Out:
#       business_status                                           geometry  \
# 0         OPERATIONAL  {'location': {'lat': 19.8673554, 'lng': 75.395...
# 1  CLOSED_TEMPORARILY  {'location': {'lat': 19.8547242, 'lng': 75.310...
# 2         OPERATIONAL  {'location': {'lat': 19.8827237, 'lng': 75.344...
# 3  CLOSED_TEMPORARILY  {'location': {'lat': 19.9558, 'lng': 75.222134...
# 4  CLOSED_TEMPORARILY  {'location': {'lat': 19.9528817, 'lng': 75.222...
#
#                           name                     place_id  \
# 0           Aurangabad Airport  ChIJh3bjGgej2zsRZp59kcFhQGc
# 1                      AR.PLAY  ChIJJ6eJVXGZ2zsRTy25c7Nbe_o
# 2  Sk Sadabahar Amusement park  ChIJx9z5l4ij2zsRKtJSO-QPaoY
# 3                H2O Waterpark  ChIJTcHd0RmR2zsRz8H3-JTVsGw
# 4          Deluxe Green Valley  ChIJ9W3noL-R2zsRrGsB7whC2qQ
#
#                                            plus_code  rating  \
# 0  {'compound_code': 'V98W+W8 Chilkalthana, Auran...     4.2
# ...

# %%
df_awb_cleaned['business_status'].value_counts()
# Out:
# CLOSED_TEMPORARILY    274
# OPERATIONAL           217
# Name: business_status, dtype: int64

# %%
df_awb_cleaned[df_awb_cleaned['tag'] == 'movie_theater']
# Out:
#         business_status                                           geometry  \
# 314         OPERATIONAL  {'location': {'lat': 19.8848645, 'lng': 75.325...
# 315  CLOSED_TEMPORARILY  {'location': {'lat': 19.8338682, 'lng': 75.248...
# 316         OPERATIONAL  {'location': {'lat': 19.87953, 'lng': 75.38284...
#
#                                                  name  \
# 314                 Khinvasara Cineplex (Amba Apsara)
# 315  Sai Ram Engineers C-189 M.I.D.C Waluj Aurangabad
# 316                               Harman Finochem Ltd
#
#                         place_id  \
# 314  ChIJUxhDCSSZ2zsR0DwM6PPPQCQ
# 315  ChIJ_x8vmhuZ2zsRi0eJx3WQAS0
# 316  ChIJsaH7k-Oi2zsRVl6ObecGSfU
#
#                                              plus_code  rating  \
# 314  {'compound_code': 'V8MG+W4 Aurangpura, Auranga...     3.6
# 315  {'compound_code': 'R6MX+GG Waluj, Aurangabad, ...     5.0
# 316  {'compound_code': 'V9HM+R4 Aurangabad, Maharas...     4.1
#
# ...

# %%
df_awb['tag'].value_counts()
# Out:
# stadium               20
# amusement_park        20
# hindu_temple          20
# campground            20
# gas_station           20
# library               20
# lodging               20
# police                20
# aquarium              20
# hospital              20
# museum                20
# spa                   20
# bar                   20
# bus_station           20
# mosque                20
# tourist_attraction    20
# church                20
# park                  20
# atm                   20
# restaurant            20
# night_club            20
# bakery                20
# cafe                  20
# taxi_stand            12
# shopping_mall         10
# movie_theater          3
# zoo                    2
# embassy                2
# book_store             2
# art_gallery            2
# light_rail_station     1
# rv_park                1
# bowling_alley          1
# train_station          1
# meal_delivery          1
# transit_station        1
# casino                 1
# ...

# %%
df.columns
# Out:
# Index(['business_status', 'formatted_address', 'geometry', 'icon', 'id',
#        'name', 'photos', 'place_id', 'plus_code', 'rating', 'reference',
#        'types', 'user_ratings_total', 'tag', 'next_page_token',
#        'no_of_results', 'permanently_closed', 'opening_hours', 'price_level',
#        'results'],
#       dtype='object')

# %%
df_awb['next_page_token'].value_counts().size
# Out:
# 22

# %%
df[['rating', 'user_ratings_total', 'name']].sort_values(by=['rating', 'user_ratings_total'], ascending=[False, False])[:20]
# Out:
#      rating  user_ratings_total                                        name
# 462     5.0                11.0                   Shree Aurangabad Property
# 231     5.0                 7.0  Jyoti Maternity Home And Sonography Clinic
# 148     5.0                 5.0             BaseCamp - Backpackers Campsite
# 311     5.0                 5.0                             Tawakkal Masjid
# 446     5.0                 5.0                           GODS OWN AYURCARE
# 36      5.0                 4.0         Betta Fish Store By Barwal Aquarium
# 324     5.0                 4.0                                Minar E Aman
# 30      5.0                 3.0            Manohar Fish Palace (Aquarium) 🐠
# 52      5.0                 3.0                           Saraswat Bank ATM
# 263     5.0                 3.0                             Papyrus Library
# 269     5.0                 3.0                         Achievers Abhyasika
# ...

# %%
d = pd.DataFrame.from_dict(d['result'].items())

# %%
d
# Out:
#                              0  \
# 0           address_components
# 1                  adr_address
# 2              business_status
# 3            formatted_address
# 4       formatted_phone_number
# 5                     geometry
# 6                         icon
# 7                           id
# 8   international_phone_number
# 9                         name
# 10                      photos
# 11                    place_id
# 12                   plus_code
# 13                 price_level
# 14                      rating
# 15                   reference
# 16                     reviews
# 17                       scope
# 18                       types
# 19                         url
# 20          user_ratings_total
# 21                  utc_offset
# 22                    vicinity
#
#                                                     1
# 0   [{'long_name': 'Jalna Road', 'short_name': 'Ja...
# 1   Shop No. 19 &amp; 20, Radhika Arcade, Near Nup...
# ...

# %%
df.iloc[0]
# Out:
# business_status                                             OPERATIONAL
# formatted_address     Shop No. 19 & 20, Radhika Arcade, Near Nupur T...
# geometry              {'location': {'lat': 19.875231, 'lng': 75.3541...
# icon                  https://maps.gstatic.com/mapfiles/place_api/ic...
# id                             2ab13cb55f576a9aead7a77d34539d79deffb2ab
# name                                                  Food-de-Bollywood
# photos                [{'height': 4608, 'html_attributions': ['<a hr...
# place_id                                    ChIJ0W8rZpCi2zsR9miRCE6PmcQ
# plus_code             {'compound_code': 'V9G3+3M Aurangabad, Maharas...
# price_level                                                           2
# rating                                                              4.2
# reference                                   ChIJ0W8rZpCi2zsR9miRCE6PmcQ
# types                 [restaurant, food, point_of_interest, establis...
# ...

# %%
df.iloc[0]['geometry']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-54898b3d9813> in <module>
# ----> 1 df.iloc[0]['geometry']
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Scraping

# %%
import requests
import json
import os
import time

# %%
tags = [
    'tourist_attraction',
    'restaurant',
    'campground',
    'amusement_park', 
    'zoo',
    'hindu_temple',
    'mosque',
    'church',
    'synagogue',
    'lodging'
]
len(tags)
# Out:
# 10

# %%
tag1 = ['tourist_attraction']

# %%
KEY = 'AIzaSyCDEKdeYkcA467-INwrPOXnU_PU_Bc2RmQ'
API = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
FIELDS = 'id,formatted_address,geometry,name,place_id,price_level,plus_code,types,rating,user_ratings_total,opening_hours,business_status'

def get_tags_data(API_KEY, tags, query_place):
    for tag in tags:
        URL = API + 'query=' + query_place + '+' + tag + '&key=' + API_KEY +\
            '&fields=' + FIELDS
        content = get_json_data(URL)
        time.sleep(10)
        check_directory_present(query_place)
        count = 1
        while('next_page_token' in content):
            file_name = '.. /data/' + query_place + '/' + query_place + '_' + \
                str(count) + '_' + tag + '.json'
            count += 1
            save_json_file(content, file_name)
            URL = API+'query='+query_place+'+'+tag+'&key='+API_KEY + \
                '&fields=' + FIELDS +'&pagetoken=' + content['next_page_token']
            content = get_json_data(URL)
            time.sleep(10)
            
        file_name = './data/' + query_place + '/' + query_place + '_' + \
            str(count) + '_' + tag + '.json'
        save_json_file(content, file_name)
        

def get_json_data(URL):
    resp = requests.get(URL)
    if resp.status_code == 200:
        JSONContent = resp.json()
    return JSONContent


def test_get(URL):
    with open('../data/goa/goa_1_tourist_attraction.json') as f:
        data = json.load(f)
    print(URL)
    return data


def check_directory_present(query_place):
    if not os.path.isdir('data'):
        os.makedirs('data')
    retval = os.getcwd()
    pat = retval + '/data/' + query_place
    if not os.path.isdir(pat):
        os.makedirs('../data/' + query_place)

        
def save_json_file(content, file_name):
    content = json.dumps(content, indent=4, sort_keys=True)
    with open(file_name, 'w') as o:
        o.write(content)
    print(f'Saved file {file_name}')

# %%
get_tags_data(KEY, tag1, 'bengaluru')
# Out:
# Saved file ./data/bengaluru/bengaluru_1_tourist_attraction.json
# Saved file ./data/bengaluru/bengaluru_2_tourist_attraction.json
# Saved file ./data/bengaluru/bengaluru_3_tourist_attraction.json

# %% [markdown]
# ## Converting JSON to CSV

# %%
import json
import numpy as np
import pandas as pd
import os 
import re

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
def create_df_from_json(direc):
    """
    This function loops through all json file in a particular sub-directory
    of `data` directory.
    Converts them into a pandas dataframe.
    """
    df_merged = pd.DataFrame()
    pat = '_([a-z]+_?[a-z]+_*[a-z]+)*(.json$)'
    directory = r'../data/' + direc
    for file in os.scandir(directory):
        if(file.path.endswith('.json')):
            with open(file, encoding='utf-8') as f:
                d = json.load(f)
            
            result = re.search(pat, file.name)
            tag = result.group(1)
            if len(d['results']) == 0:
                df = pd.DataFrame.from_dict({'results': [0]})
            else:
                df = pd.DataFrame.from_dict(d['results'])
            df['tag'] = tag
        
        if df_merged.empty:
            df_merged = df
        else:
            df_merged = pd.concat([df_merged, df], axis=0, ignore_index=True)
    df_merged.to_csv('../data/csv/' + direc + '.csv')

# %%
cities = ['aurangabad', 'agra', 'delhi', 'goa', 'jaipur']

for city in cities:
    create_df_from_json(city)

# %%
cities = ['jammu', 'bengaluru']

for city in cities:
    create_df_from_json(city)

# %% [markdown]
# ## EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', None)

# %%
df_awb = df_awb.drop_duplicates(subset='name', keep='first')
df_agra = df_agra.drop_duplicates(subset='name', keep='first')
df_dli = df_dli.drop_duplicates(subset='name', keep='first')
df_goa = df_goa.drop_duplicates(subset='name', keep='first')
df_jai = df_jai.drop_duplicates(subset='name', keep='first')

# %%
df_awb = pd.read_csv('data/csv/aurangabad.csv')
df_agra = pd.read_csv('data/csv/agra.csv')
df_dli = pd.read_csv('data/csv/delhi.csv')
df_goa = pd.read_csv('data/csv/goa.csv')
df_jai = pd.read_csv('data/csv/jaipur.csv')

# %%
df_awb.head()
# Out:
#       business_status  \
# 0  CLOSED_TEMPORARILY
# 1         OPERATIONAL
# 2  CLOSED_TEMPORARILY
# 3  CLOSED_TEMPORARILY
# 4         OPERATIONAL
#
#                                                                                                                 formatted_address  \
# 0  BACKSIDE OF PATEL LAWNS, H.NO137 P.NO37 ABRAR COLONY NYAR MARWAH MASJID, Beed Bypass Rd, Aurangabad, Maharashtra 431005, India
# 1                                                            3-8-286, Sanjay Nagar, Mondha, Aurangabad, Maharashtra 431001, India
# 2                                      NH 211, Vitkheda - Ellora Rd, near Daulatabad, Fort, Daulatabad, Maharashtra 431005, India
# 3                                                                                           Daulatabad, Maharashtra 431002, India
# 4                     Ellora Road, Next to H2O Waterpark, Daulatabad, National Highway 211, Aurangabad, Maharashtra 431002, India
#
# ...

# %%
def clean_data(df):
    '''Remove unnecessary columns. Fill none values. 
    Convert geometry column to lat long.
    Returns the cleaned df.'''
    df.fillna(value=-1, inplace=True)
    df['lat'] = df['geometry'].str.split(' ', 2).str.get(2).str.split(',', 
                    0).str.get(0).astype(float)
    df['long'] = df['geometry'].str.split(' ', 4).str.get(4).str.split('}', 
                    0).str.get(0).astype(float)
    df.drop(['Unnamed: 0', 'geometry', 'icon', 'id', 'photos', 'reference'], 
            axis=1, inplace=True)
    df = df.drop_duplicates(subset='name', keep='first')
    return df

# %%
df_awb = clean_data(df_awb)
df_goa = clean_data(df_goa)
df_dli = clean_data(df_dli)
df_agra = clean_data(df_agra)
df_jai = clean_data(df_jai)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'geometry'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-4f06882ea430> in <module>
# ----> 1 df_awb = clean_data(df_awb)
# ...

# %%
df_awb = pd.read_csv('data/csv/aurangabad.csv')
df_agra = pd.read_csv('data/csv/agra.csv')
df_dli = pd.read_csv('data/csv/delhi.csv')
df_goa = pd.read_csv('data/csv/goa.csv')
df_jai = pd.read_csv('data/csv/jaipur.csv')

# %%
df_awb.to_csv('./data/ext/aurangabad.csv')
df_goa.to_csv('./data/ext/goa.csv')
df_dli.to_csv('./data/ext/delhi.csv')
df_agra.to_csv('./data/ext/agra.csv')
df_jai.to_csv('./data/ext/jaipur.csv')

# %%
df_awb = clean_data(df_awb)

# %%
df_awb.columns
# Out:
# Index(['business_status', 'formatted_address', 'name', 'permanently_closed',
#        'place_id', 'plus_code', 'rating', 'types', 'user_ratings_total',
#        'opening_hours', 'tag', 'price_level', 'lat', 'long'],
#       dtype='object')

# %%
df_awb['business_status'].value_counts()
# Out:
# CLOSED_TEMPORARILY    253
# OPERATIONAL           173
# -1                      6
# Name: business_status, dtype: int64

# %%
df_awb['tourist_type'] = df_awb['types'].apply(lambda x: True if
                    (('tourist_attraction' in x) and ('store' not in x) and
                     ('travel_agency' not in x) and ('place_of_worship' not \
                     in x)) else False)
df_awb[['name', 'types', 'tourist_type', 'tag']].where( \
                    (df_awb['tourist_type']==True)).dropna()
# Out:
#                                    name  \
# 6       Vardhman Fantasy Amusement Park
# 7              On Wheelz Amusement Park
# 8                            EsselWorld
# 9                         Dinosaur Park
# 10              Wonderla Amusement Park
# 11                    Agrawal Appu Ghar
# 12            Fun N Food Village Nagpur
# 13               Sayajiraje Park, Akluj
# 16                  Maniar's Wonderland
# 17                       Tikuji-ni-Wadi
# 18                             Imagicaa
# 19                Wonderland, Jalandhar
# 25                       Goga Baba Hill
# 32         Pawna Lake Camping Pawnacamp
# 145                     Bibi Ka Maqbara
# 162            Siddharth Garden and Zoo
# 165                        Himayat Bagh
# 168  Chhatrapati Shivaji Maharaj Museum
# 169         Aurangabad Caves View Point
# 170                        Soneri Mahal
# 171            Pallawankur Agro Tourism
# 176                       Kanchan Hills
# ...

# %%
df_awb.where(df_awb['tourist_type']==True).sort_values(by='rating', ascending=False)[['name', 'rating']][:10]
# Out:
#                                    name  rating
# 327  Aurangabad Himroo (factory+outlet)     4.8
# 312             Gateway Of India Mumbai     4.6
# 10              Wonderla Amusement Park     4.5
# 25                       Goga Baba Hill     4.5
# 8                            EsselWorld     4.4
# 321                     Daulatabad fort     4.4
# 334                          Delhi Gate     4.4
# 18                             Imagicaa     4.4
# 32         Pawna Lake Camping Pawnacamp     4.3
# 165                        Himayat Bagh     4.3

# %%
df_awb['restaurant_type'] = df_awb['types'].apply(lambda x: True if
                    (('restaurant' in x)) else False)
df_awb[['name', 'types', 'restaurant_type']].where((df_awb['restaurant_type']\
                                                 ==True)).dropna()
# Out:
#                                                 name  \
# 4                                        Hotel Lotus
# 12                         Fun N Food Village Nagpur
# 24                  Hiranya Resorts - Full of Nature
# 80                                 Ginger Aurangabad
# 120                     Sai Panchvati Veg Restaurant
# 121                        Jalsa Restaurant Pure Veg
# 122                      Patelsaab Family Restaurant
# 123                                Flames Restaurant
# 124                                     Laadli Hotel
# 125                                   Hotel Dashmesh
# 126                         Surbhi Family Restaurant
# 127      Barbeque Nation - Aurangabad - Prozone Mall
# 128                       Balaji South Indian Center
# 129                                    Surajcreation
# 130              Little Italy Restaurant, Aurangabad
# 131                                       Veg Petals
# 132                    Mrignayani Restaurant and Bar
# ...

# %%
df_awb['religious_type'] = df_awb['types'].apply(lambda x: True if
                    (('hindu_temple' in x) or ('church' in x) or ('mosque'\
                     in x) or ('synagogue' in x)) else False)
df_awb[['name', 'types', 'religious_type']].where((df_awb['religious_type']\
                                                 ==True)).dropna()
# Out:
#                                                                 name  \
# 40                                                St. Thomas’ Church
# 41                                  St. John The Evangelist's Church
# 42                              PEACE MEMORIAL NAZARENE CHURCH CIDCO
# 43                                                Church Of Nazarene
# 44                                        Orthodox Church Aurangabad
# 45                                            Church Of The Nazarene
# 46                                  Indian Pentacostal Church Of God
# 47                                             Prist Nazarene Church
# 48                                 Christ Church Girls & Boys Hostel
# 49                                               Holy Trinity Church
# 50                                       Christian Fellowship Church
# 51                                       Evangelical Church Of India
# 52                                                         AG CHURCH
# ...

# %%
df_awb['park_type'] = df_awb['types'].apply(lambda x: True if
                    (('campground' in x) or ('amusement_park' in x) or
                     ('zoo' in x)) else False)
df_awb[['name', 'types', 'park_type']].where((df_awb['park_type']\
                                                 ==True)).dropna()
# Out:
#                                                                                              name  \
# 0                                                                                         AR.PLAY
# 2                                                                                   H2O Waterpark
# 3                                                                             Deluxe Green Valley
# 4                                                                                     Hotel Lotus
# 5                                                                                  Magic Mountain
# 6                                                                 Vardhman Fantasy Amusement Park
# 7                                                                        On Wheelz Amusement Park
# 8                                                                                      EsselWorld
# ...

# %%
df_awb['lodging_type'] = df_awb['types'].apply(lambda x: True if
                    (('lodging' in x)) else False)
df_awb[['name', 'types', 'lodging_type']].where((df_awb['lodging_type']\
                                                 ==True)).dropna()
# Out:
#                                                                                              name  \
# 4                                                                                     Hotel Lotus
# 12                                                                      Fun N Food Village Nagpur
# 15                                                   Ajwa Fun World, Ajwa Water Park, Ajwa Resort
# 20                                                                          Chhawni Eidgah Maidan
# 21                                                                   Aditya Krushi Parytan Kendra
# 22                                                                BaseCamp - Backpackers Campsite
# 23                                                                                  Holi festival
# 24                                                               Hiranya Resorts - Full of Nature
# ...

# %% [markdown]
# ## Sorted values

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import json

# %%
def city_data(city):
    '''This function takes in the city and returns it df.
    '''
    cities = ['aurangabad', 'agra', 'delhi', 'goa', 'jaipur']
    if city in cities:
        df = pd.read_csv('./data/csv/' + city + '.csv')
        return df
    else:
        print(f'The city is not in list: {cities}')
        return None

# %%
def location_data_sorted(city):
    df = city_data(city)
    df['tourist'] = df[df['tag']=='tourist_attraction']['types'].apply(\
        lambda x: \
                True if(('travel_agency' not in x) and ('car_rental' not in \
                        x) and ('taxi_stand' not in x) and ('political' not \
                        in x) and ('lodging' not in x)) else False)
    df['n_type'] = df['name'].apply(lambda x: True if(('tours' not in \
                        x.lower()) and ('rental' not in x.lower()) and \
                        ('taxi' not in x.lower())) else False)
    req_df = df[(df['tourist']==True) & (df['n_type']==True)]
    tour = req_df.sort_values(by=['rating', 'user_ratings_total'], 
                             ascending=[False, False])[['name', 'rating']]
    df['rel']=df['types'].apply(lambda x: True if('place_of_worship' in x)\
                        else False)
    rel = df[df['rel']==True].sort_values(by=['rating', 'user_ratings_total'],
                              ascending=[False, False])[['name', 'rating']]
    df['rest'] = df['types'].apply(lambda x: True if('restaurant' in x) else\
                            False)
    rest=df[df['rest']==True].sort_values(by=['rating', 'user_ratings_total'],
                              ascending=[False, False])[['name', 'rating']]
    req_df = df[df['tag']=='lodging']
    lod = req_df.sort_values(by=['rating', 'user_ratings_total'],
                              ascending=[False, False])[['name', 'rating']]
    df['park'] = df['types'].apply(lambda x: True if('campground' in x) or 
                            ('amusement_park' in x) or ('zoo' in x) else False)
    park = df[df['park']==True].sort_values(by=['rating','user_ratings_total'],
                            ascending=[False, False])[['name', 'rating']]
    
    x = pd.DataFrame()
    x['tourist_attraction'] = tour['name'][:10].values
    x['religious'] = rel['name'][:10].values
    x['restaurant'] = rest['name'][:10].values
    x['lodging'] = lod['name'][:10].values
    x['parks'] = park['name'][:10].values
    x = x.to_json()
    
    return x

# %%
data = location_data_sorted('agra')

# %%
type(data)
# Out:
# str

# %% [markdown]
# ## Test

# %%
awb = pd.read_csv('../data1/csv/aurangabad.csv')
goa = pd.read_csv('../data1/csv/goa.csv')

# %%
req_df = awb[awb['tag'] == 'tourist_attraction'][['name']]

# %%
req_df.to_excel('test.xlsx')

# %%
ben = pd.read_csv('../data/csv/bengaluru.csv')
jam = pd.read_csv('../data/csv/jammu.csv')

# %%
ben[['name', 'types']].to_csv('ben.csv')
jam[['name', 'types']].to_csv('jam.csv')
